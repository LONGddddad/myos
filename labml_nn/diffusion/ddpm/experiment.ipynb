# %% [markdown]
# [![Github](https://img.shields.io/github/stars/labmlai/annotated_deep_learning_paper_implementations?style=social)](https://github.com/labmlai/annotated_deep_learning_paper_implementations)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/labmlai/annotated_deep_learning_paper_implementations/blob/master/labml_nn/diffusion/ddpm/experiment.ipynb)
#
# ## [Denoising Diffusion Probabilistic Models (DDPM)](https://nn.labml.ai/diffusion/ddpm/index.html)
#
# This notebook trains a DDPM based model on MNIST digits dataset.

# %% [markdown]
# ### Install the packages

# %%
# !pip install labml-nn --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 8.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.9/443.9 kB 15.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 54.0 MB/s eta 0:00:00
#   Building wheel for fairscale (pyproject.toml) ... done

# %% [markdown]
# ### Imports

# %%
import torch
import torch.nn as nn

from labml import experiment
from labml.configs import option
from labml_nn.diffusion.ddpm.experiment import Configs

# %% [markdown]
# ### Create an experiment

# %%
experiment.create(name="diffuse", writers={'screen'})

# %% [markdown]
# ### Configurations

# %%
configs = Configs()

# %% [markdown]
# Set experiment configurations and assign a configurations dictionary to override configurations

# %%
experiment.configs(configs, {
    'dataset': 'MNIST',
    'image_channels': 1,
    'epochs': 5,
})
# Out:
# <pre style="overflow-x: scroll;"></pre>

# %% [markdown]
# Initializ

# %%
configs.init()
# Out:
# <pre style="overflow-x: scroll;">Prepare device.device...
#   Prepare device.device_info<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	77.42ms</span>
# Prepare device.device<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	81.30ms</span>
# Prepare dataset<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	28,228.59ms</span>
# </pre>
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to /content/data/MNISTDataset/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:11<00:00, 898kB/s]
# Extracting /content/data/MNISTDataset/raw/train-images-idx3-ubyte.gz to /content/data/MNISTDataset/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to /content/data/MNISTDataset/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 64.5kB/s]
# Extracting /content/data/MNISTDataset/raw/train-labels-idx1-ubyte.gz to /content/data/MNISTDataset/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to /content/data/MNISTDataset/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:06<00:00, 245kB/s]
# Extracting /content/data/MNISTDataset/raw/t10k-images-idx3-ubyte.gz to /content/data/MNISTDataset/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to /content/data/MNISTDataset/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 2.84MB/s]
# Extracting /content/data/MNISTDataset/raw/t10k-labels-idx1-ubyte.gz to /content/data/MNISTDataset/raw

# %% [markdown]
# Set PyTorch models for loading and saving

# %%
experiment.add_pytorch_models({'eps_model': configs.eps_model})

# %% [markdown]
# ### Start the experiment and run the training loop.

# %%
# Start the experiment
with experiment.start():
    configs.run()
# Out:
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">233a71ba9ab311ef81160242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   404,973ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 55,275ms  </span> loss: <span style="color: #C5C1B4">0.020059</span>  <span style="color: #208FFB">460,249ms</span><span style="color: #D160C4">  0:07m/  0:30m  </span>
# <strong><span style="color: #DDB62B">   1,132:  </span></strong>Train:<span style="color: #C5C1B4">  20%</span><span style="color: #208FFB">   406,808ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 55,275ms  </span> loss: <strong>0.036438</strong>  <span style="color: #208FFB">468,053ms</span><span style="color: #D160C4">  0:09m/  0:29m  </span></pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-0842d783e611> in <cell line: 2>()
#       1 # Start the experiment
#       2 with experiment.start():
# ----> 3     configs.run()
#
# /usr/local/lib/python3.10/dist-packages/labml_nn/diffusion/ddpm/experiment.py in run(self)
#     150         for _ in monit.loop(self.epochs):
#     151             # Train the model
# --> 152             self.train()
#     153             # Sample some images
#     154             self.sample()
#
# /usr/local/lib/python3.10/dist-packages/labml_nn/diffusion/ddpm/experiment.py in train(self)
#     142             self.optimizer.step()
#     143             # Track the loss
# --> 144             tracker.save('loss', loss)
#     145
#     146     def run(self):
#
# /usr/local/lib/python3.10/dist-packages/labml/tracker.py in save(*args, **kwargs)
#     323         add(*args, **kwargs)
#     324
# --> 325     _internal().write()
#     326
#     327
#
# /usr/local/lib/python3.10/dist-packages/labml/internal/tracker/__init__.py in write(self)
#      80         for w in self.__writers:
#      81             if isinstance(w, ScreenWriter):
# ---> 82                 indicators_print = self._write_writer(w, global_step)
#      83             else:
#      84                 self._write_writer(w, global_step)
#
# /usr/local/lib/python3.10/dist-packages/labml/internal/tracker/__init__.py in _write_writer(self, writer, global_step)
#      64
#      65     def _write_writer(self, writer: Writer, global_step):
# ---> 66         return writer.write(global_step=global_step,
#      67                             indicators=self.indicators)
#      68
#
# /usr/local/lib/python3.10/dist-packages/labml/internal/tracker/writers/screen.py in write(self, global_step, indicators)
#     199         self._print_artifacts(indicators)
#     200
# --> 201         return self._get_indicator_string(indicators)
#
# /usr/local/lib/python3.10/dist-packages/labml/internal/tracker/writers/screen.py in _get_indicator_string(self, indicators)
#      72
#      73             if not ind.is_empty():
# ---> 74                 v = ind.get_mean()
#      75                 self.update_estimate(ind.name, v)
#      76                 value = self.get_value_string(ind.name, v)
#
# /usr/local/lib/python3.10/dist-packages/labml/internal/tracker/indicators/numeric.py in get_mean(self)
#      94
#      95     def get_mean(self) -> float:
# ---> 96         return float(np.mean(self._merge()))
#      97
#      98     def get_histogram(self):
#
# /usr/local/lib/python3.10/dist-packages/labml/internal/tracker/indicators/numeric.py in _merge(self)
#      76             return []
#      77         elif len(self._values) == 1:
# ---> 78             return to_numpy(self._values[0]).ravel()
#      79         else:
#      80             values = [to_numpy(v).ravel() for v in self._values]
#
# /usr/local/lib/python3.10/dist-packages/labml/internal/util/values.py in to_numpy(value)
#      31             return _torch_to_numpy(value.data)
#      32         elif isinstance(value, torch.Tensor):
# ---> 33             return _torch_to_numpy(value)
#      34
#      35     try:
#
# /usr/local/lib/python3.10/dist-packages/labml/internal/util/values.py in _torch_to_numpy(tensor)
#       5     import torch
#       6     with torch.no_grad():
# ----> 7         tensor = tensor.cpu()
#       8         if tensor.dtype == torch.bfloat16:
#       9             tensor = tensor.to(torch.float)
#
# KeyboardInterrupt:
